# %%
import pandas as pd

# %%
nyc=pd.read_csv("/content/ave_hi_nyc_jan_1895-2018 (1).csv", header='infer')

# %%
nyc
# Out:
#        Date  Value  Anomaly
# 0    189501   34.2     -3.2
# 1    189601   34.7     -2.7
# 2    189701   35.5     -1.9
# 3    189801   39.6      2.2
# 4    189901   36.4     -1.0
# ..      ...    ...      ...
# 119  201401   35.5     -1.9
# 120  201501   36.1     -1.3
# 121  201601   40.8      3.4
# 122  201701   42.8      5.4
# 123  201801   38.7      1.3
#
# [124 rows x 3 columns]

# %%
nyc.columns
# Out:
# Index(['Date', 'Value', 'Anomaly'], dtype='object')

# %%
nyc.columns=['Date', 'Temperature', 'Anomaly']

# %%
nyc.head(6)
# Out:
#      Date  Temperature  Anomaly
# 0  189501         34.2     -3.2
# 1  189601         34.7     -2.7
# 2  189701         35.5     -1.9
# 3  189801         39.6      2.2
# 4  189901         36.4     -1.0
# 5  190001         37.4      0.0

# %%
nyc.sample(20)
# Out:
#        Date  Temperature  Anomaly
# 38   193301         45.6      8.2
# 70   196501         34.0     -3.4
# 113  200801         42.4      5.0
# 76   197101         31.5     -5.9
# 95   199001         46.0      8.6
# 64   195901         37.1     -0.3
# 25   192001         29.7     -7.7
# 101  199601         37.0     -0.4
# 13   190801         38.3      0.9
# 112  200701         43.6      6.2
# 28   192301         35.2     -2.2
# 57   195201         42.4      5.0
# 67   196201         38.0      0.6
# 11   190601         42.3      4.9
# 89   198401         33.5     -3.9
# 35   193001         38.5      1.1
# 48   194301         36.1     -1.3
# 27   192201         33.4     -4.0
# 60   195501         35.6     -1.8
# 37   193201         47.6     10.2

# %%
nyc.info
# Out:
# <bound method DataFrame.info of        Date  Temperature  Anomaly
# 0    189501         34.2     -3.2
# 1    189601         34.7     -2.7
# 2    189701         35.5     -1.9
# 3    189801         39.6      2.2
# 4    189901         36.4     -1.0
# ..      ...          ...      ...
# 119  201401         35.5     -1.9
# 120  201501         36.1     -1.3
# 121  201601         40.8      3.4
# 122  201701         42.8      5.4
# 123  201801         38.7      1.3
#
# [124 rows x 3 columns]>

# %%
nyc.tail(6)
# Out:
#        Date  Temperature  Anomaly
# 118  201301         40.8      3.4
# 119  201401         35.5     -1.9
# 120  201501         36.1     -1.3
# 121  201601         40.8      3.4
# 122  201701         42.8      5.4
# 123  201801         38.7      1.3

# %%
nyc.shape
# Out:
# (124, 3)

# %%
nyc.Date=nyc.Date.floordiv(100)

# %%
nyc.head()
# Out:
#    Date  Temperature  Anomaly
# 0  1895         34.2     -3.2
# 1  1896         34.7     -2.7
# 2  1897         35.5     -1.9
# 3  1898         39.6      2.2
# 4  1899         36.4     -1.0

# %%
nyc.tail()
# Out:
#      Date  Temperature  Anomaly
# 119  2014         35.5     -1.9
# 120  2015         36.1     -1.3
# 121  2016         40.8      3.4
# 122  2017         42.8      5.4
# 123  2018         38.7      1.3

# %%
from sklearn.model_selection import train_test_split

# %%
nyc['Date'].values
# Out:
# array([1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905,
#        1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916,
#        1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927,
#        1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938,
#        1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949,
#        1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
nyc['Temperature'].values
# Out:
# array([34.2, 34.7, 35.5, 39.6, 36.4, 37.4, 37. , 35. , 35.5, 29.8, 33.7,
#        42.3, 40.5, 38.3, 39.6, 36.1, 40.7, 29.3, 46.9, 36.9, 38.9, 42.3,
#        38.4, 26.5, 40.6, 29.7, 39.7, 33.4, 35.2, 39.4, 33.8, 37.2, 36.8,
#        40. , 37.8, 38.5, 38.2, 47.6, 45.6, 39.8, 35. , 34.3, 45.7, 37.3,
#        36.8, 30. , 34.5, 36.5, 36.1, 39. , 31.5, 40.2, 43. , 30.1, 43.5,
#        47.6, 42.5, 42.4, 42.4, 37. , 35.6, 36.2, 33.8, 36.4, 37.1, 37.8,
#        31.9, 38. , 34.6, 40.2, 34. , 37.1, 41.6, 31.7, 35.7, 29.9, 31.5,
#        40.5, 40.6, 39.7, 41.7, 32.6, 26.1, 32.3, 38.6, 38. , 30.6, 30.9,
#        38. , 33.5, 33. , 39.3, 35.9, 34.2, 42.4, 46. , 39.6, 40.9, 41. ,
#        31.6, 42.6, 37. , 39.2, 45.8, 40.8, 37.8, 38.8, 45.4, 32.9, 31. ,
#        37.4, 47.6, 43.6, 42.4, 33.4, 38.1, 34.8, 44.2, 40.8, 35.5, 36.1,
#        40.8, 42.8, 38.7])

# %%
X_train, X_test, y_train, y_test=train_test_split(nyc.Date.values.reshape(-1,1), nyc.Temperature.values, random_state=11)

# %%
X_train.shape
# Out:
# (93, 1)

# %%
X_test.shape
# Out:
# (31, 1)

# %%
31+93
# Out:
# 124

# %%
31/124*100
# Out:
# 25.0

# %%
X_train[0]
# Out:
# array([1996])

# %%
y_train[0]
# Out:
# 37.0

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression=LinearRegression()

# %%
linear_regression
# Out:
# LinearRegression()

# %%
linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([0.01939167])

# %%
import seaborn as sns

# %%
axes=sns.scatterplot(data=nyc, x='Date', y='Temperature', hue='Temperature', palette='winter',legend=False )

# %% [markdown]
# f(x) = mX + C

# %%
linear_regression.intercept_
# Out:
# -0.30779820252656265

# %%
def predict(x):
  return x*linear_regression.coef_ + linear_regression.intercept_

# %%
predict(2070)
# Out:
# array([39.83296552])

# %%
predict(1000)
# Out:
# array([19.08387509])

# %%
import seaborn as sns

# %%
axes=sns.scatterplot(data=nyc, x='Date', y='Temperature', hue='Temperature', palette='winter', legend=False)
axes.set_ylim(10,70)
import numpy as np
x=np.array([min(nyc.Date.values), max(nyc.Date.values)])
y=predict(x)
import matplotlib.pyplot as plt
line=plt.plot(x,y)

# %%
from sklearn.metrics import mean_squared_error

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
# 50% training and 50% testing
X_train_50, X_test_50, y_train_50, y_test_50 = train_test_split(nyc.Date.values.reshape(-1, 1), nyc.Temperature.values, test_size=0.5, random_state=11)

linear_regression_50 = LinearRegression()
linear_regression_50.fit(X=X_train_50, y=y_train_50)
predicted_50 = linear_regression_50.predict(X_test_50)

for p, e in zip(predicted_50, y_test_50):
    print(f"predicted: {p:.2f}, expected: {e:.2f}")

rmse_50 = rmse(y_test_50, predicted_50)
print(f"RMSE: {rmse_50:.2f}")
# Out:
# predicted: 37.08, expected: 31.70
# predicted: 36.18, expected: 35.50
# predicted: 37.13, expected: 40.50
# predicted: 36.27, expected: 29.80
# predicted: 36.36, expected: 40.70
# predicted: 37.62, expected: 34.80
# predicted: 36.16, expected: 34.20
# predicted: 36.61, expected: 38.20
# predicted: 36.93, expected: 36.20
# predicted: 36.86, expected: 42.50
# predicted: 36.52, expected: 39.40
# predicted: 37.38, expected: 40.90
# predicted: 36.65, expected: 39.80
# predicted: 37.47, expected: 40.80
# predicted: 36.23, expected: 37.00
# predicted: 36.69, expected: 45.70
# predicted: 37.29, expected: 33.00
# predicted: 37.10, expected: 29.90
# predicted: 37.27, expected: 38.00
# predicted: 37.58, expected: 42.40
# predicted: 37.20, expected: 32.30
# predicted: 36.54, expected: 33.80
# predicted: 36.60, expected: 38.50
# predicted: 36.98, expected: 37.80
# predicted: 36.35, expected: 36.10
# predicted: 36.94, expected: 33.80
# predicted: 36.89, expected: 42.40
# ...

# %%
# 80% training and 20% testing
X_train_80, X_test_80, y_train_80, y_test_80 = train_test_split(nyc.Date.values.reshape(-1, 1), nyc.Temperature.values, test_size=0.2, random_state=11)

linear_regression_80 = LinearRegression()
linear_regression_80.fit(X=X_train_80, y=y_train_80)
predicted_80 = linear_regression_80.predict(X_test_80)

for p, e in zip(predicted_80, y_test_80):
    print(f"predicted: {p:.2f}, expected: {e:.2f}")

rmse_80 = rmse(y_test_80, predicted_80)
print(f"RMSE: {rmse_80:.2f}")
# Out:
# predicted: 37.84, expected: 31.70
# predicted: 36.80, expected: 35.50
# predicted: 37.90, expected: 40.50
# predicted: 36.90, expected: 29.80
# predicted: 37.00, expected: 40.70
# predicted: 38.47, expected: 34.80
# predicted: 36.77, expected: 34.20
# predicted: 37.30, expected: 38.20
# predicted: 37.67, expected: 36.20
# predicted: 37.59, expected: 42.50
# predicted: 37.20, expected: 39.40
# predicted: 38.20, expected: 40.90
# predicted: 37.34, expected: 39.80
# predicted: 38.30, expected: 40.80
# predicted: 36.86, expected: 37.00
# predicted: 37.39, expected: 45.70
# predicted: 38.09, expected: 33.00
# predicted: 37.87, expected: 29.90
# predicted: 38.06, expected: 38.00
# predicted: 38.43, expected: 42.40
# predicted: 37.99, expected: 32.30
# predicted: 37.21, expected: 33.80
# predicted: 37.28, expected: 38.50
# predicted: 37.72, expected: 37.80
# predicted: 36.99, expected: 36.10
# RMSE: 4.01

# %%
# 90% training and 10% testing
X_train_90, X_test_90, y_train_90, y_test_90 = train_test_split(nyc.Date.values.reshape(-1, 1), nyc.Temperature.values, test_size=0.1, random_state=11)

linear_regression_90 = LinearRegression()
linear_regression_90.fit(X=X_train_90, y=y_train_90)
predicted_90 = linear_regression_90.predict(X_test_90)

for p, e in zip(predicted_90, y_test_90):
    print(f"predicted: {p:.2f}, expected: {e:.2f}")

rmse_90 = rmse(y_test_90, predicted_90)
print(f"RMSE: {rmse_90:.2f}")
# Out:
# predicted: 37.77, expected: 31.70
# predicted: 36.78, expected: 35.50
# predicted: 37.83, expected: 40.50
# predicted: 36.88, expected: 29.80
# predicted: 36.98, expected: 40.70
# predicted: 38.37, expected: 34.80
# predicted: 36.76, expected: 34.20
# predicted: 37.26, expected: 38.20
# predicted: 37.61, expected: 36.20
# predicted: 37.54, expected: 42.50
# predicted: 37.16, expected: 39.40
# predicted: 38.11, expected: 40.90
# predicted: 37.30, expected: 39.80
# RMSE: 3.67

# %%
# 75% training and 25% testing
X_train_75, X_test_75, y_train_75, y_test_75 = train_test_split(nyc.Date.values.reshape(-1, 1), nyc.Temperature.values, test_size=0.25, random_state=11)

linear_regression_75 = LinearRegression()
linear_regression_75.fit(X=X_train_75, y=y_train_75)
predicted_75 = linear_regression_75.predict(X_test_75)

for p, e in zip(predicted_75, y_test_75):
    print(f"predicted: {p:.2f}, expected: {e:.2f}")

rmse_75 = rmse(y_test_75, predicted_75)
print(f"RMSE: {rmse_75:.2f}")
# Out:
# predicted: 37.86, expected: 31.70
# predicted: 36.48, expected: 35.50
# predicted: 37.93, expected: 40.50
# predicted: 36.61, expected: 29.80
# predicted: 36.75, expected: 40.70
# predicted: 38.69, expected: 34.80
# predicted: 36.44, expected: 34.20
# predicted: 37.14, expected: 38.20
# predicted: 37.62, expected: 36.20
# predicted: 37.53, expected: 42.50
# predicted: 37.00, expected: 39.40
# predicted: 38.32, expected: 40.90
# predicted: 37.20, expected: 39.80
# predicted: 38.46, expected: 40.80
# predicted: 36.56, expected: 37.00
# predicted: 37.25, expected: 45.70
# predicted: 38.18, expected: 33.00
# predicted: 37.89, expected: 29.90
# predicted: 38.15, expected: 38.00
# predicted: 38.63, expected: 42.40
# predicted: 38.05, expected: 32.30
# predicted: 37.02, expected: 33.80
# predicted: 37.12, expected: 38.50
# predicted: 37.70, expected: 37.80
# predicted: 36.73, expected: 36.10
# predicted: 37.64, expected: 33.80
# predicted: 37.56, expected: 42.40
# ...

# %% [markdown]
# # COMMENTS
# training %	testing %	RMSE	comments
# 50	              50	4.55	a smaller training data leads to poorer performance
# 80	              20	4.01	better than the 50% split but not as good as the 90% split.
# 90	              10	3.67	has the lowest rmse because it has the highest training data
# 75	              25	4.16	split shows an RMSE of 4.16 which is slightly
#                             worse than the 80% split but better than the 50% split.

# %%
# COMMENTS
training %	testing %	RMSE	comments
50	              50	4.55	a smaller training data leads to poorer performance
80	              20	4.01	better than the 50% split but not as good as the 90% split.
90	              10	3.67	has the lowest rmse because it has the highest training data
75	              25	4.16	split shows an RMSE of 4.16 which is slightly
                            worse than the 80% split but better than the 50% split.
# Out:
#   File "<ipython-input-45-22f3d6730f10>", line 2
#     training %	testing %	RMSE	comments
#               	         	    	^
# SyntaxError: invalid syntax
